# %% [raw]
# ---
# title: "Methods for the Classification of Data from Open-Ended Questions in Surveys"
# subtitle: "Disputation<br>16 April 2024"
# author:
#   - name: Camille Landesvatter
#     #email: camille.landesvatter@uni-mannheim.de
#     affiliations:
#       - name: University of Mannheim
# format:
#   revealjs:
#     theme: [white, custom.css]
#     #theme: default
#     #theme: simple
#     footer: "Landesvatter: Methods for the Classification of Data from Open-Ended Questions in Surveys"
#     embed-resources: true
#     slide-number: true
#     preview-links: auto
#     #logo: images/quarto.png
#     #show-slide-number: print
# ---

# %% [markdown]
# ## Research Objective
#
# <font size = "7"><blockquote>"[...] introducing various <span style="color:blue">methods</span> of classifying <span style="color:blue">data from open-ended survey questions</span> and empirically illustrating their application. A central research question addressed in this thesis therefore concerns the analysis of <span style="color:blue">(short) text data</span> generated by open-ended survey questions." (Landesvatter 2023, p.2) </blockquote></font size>

# %% [raw]
# ---
#
# ## Open-Ended Questions in Surveys
#
#
# ---

# %% [markdown]
# ## Methods for Analyzing Data from Open-Ended Questions
#
# - show methods stack with literature

# %% [raw]
# ---
#
# ## Motivation
#
# - the increase in methods to collect open-ended answers (e.g. smartphone-administered surveys, voice technologies) calls for testing and validating automated methods to analyze the resulting data
#
# 1. Why did I chose the Survey Context?
# - survey answers pose a special context for applying machine learning based classification methods
# - due to their short and concise structure of open-ended answers (e.g., Zhu et al. 2022)
# - requires the use of suitable methods
# - e.g., word embeddings, structural topic models
#
# 2. Why do I focus on computational methods?
# - human error ...
# - etc ..
#
#
# ---

# %% [markdown]
# ## <font size = "12">Empirical contributions</font size> {.center}
#
#
# ```{css}
# .center h2 {
#   text-align: center;
# }
# ```

# %% [raw]
# ---
#
# ## Empirical contributions: Overview
#
# | 1             | 2             | 3            |
# | ------------- | ------------- | ------------ |
# | title paper 1 | title paper 2 | tile paper 2 |
#
#
# - Data Collection approach: three self-administered web surveys with open-ended questions
# - Methodology for text classification: supervised ML, unsupervised ML, fine-tuning of pre-trained language model BERT, zero-shot learning
#
# ---

# %% [markdown]
# ## Empirical contributions: Methods
# - name all methods I used in the dissertation
# - compare / overlap methods from the papers with overview slide

# %% [raw]
# ---
#
# ## How valid are trust survey measures? New insights from open-ended probing data and supervised machine learning (I)
#
# Co-authored by: Dr. Paul C. Bauer
# Published In: ...
#
# ---

# %% [markdown]
# ## How valid are trust survey measures? New insights from open-ended probing data and supervised machine learning (I)
#
# - background (1 sentence) in terms of methods
# <!-- - previous research (1 sentence) -->
# - research question !!
# <!-- - hypotheses -->
# - data & questionnaire (very short, keywords only)
# - experimental design (very short, keywords only)
# - methods !!
# - results !!
# <!-- - limitations -->

# %% [raw]
# ---
#
# ## How valid are trust survey measures? New insights from open-ended probing data and supervised machine learning (II)
#
#
#
# ---

# %% [markdown]
# ## How valid are trust survey measures? New insights from open-ended probing data and supervised machine learning (III)

# %% [raw]
# ---
#
# ## Open-ended survey questions: A comparison of information content in text and audio response formats (I)
#
# Co-authored by: Dr. Paul C. Bauer
# Under Review In: ...
#
# ---

# %% [markdown]
# ## Open-ended survey questions: A comparison of information content in text and audio response formats (I)

# %% [raw]
# ---
#
# ## Open-ended survey questions: A comparison of information content in text and audio response formats (II)
#
#
# ---

# %% [markdown]
# ## Open-ended survey questions: A comparison of information content in text and audio response formats (III)

# %% [raw]
# ---
#
# ## Asking Why: Is there an Affective Component of Political Trust Ratings in Surveys? (I)
#
# Co-authored by: Dr. Paul C. Bauer
# Under Review In: ...
#
#
#
# ---

# %% [markdown]
# ## Asking Why: Is there an Affective Component of Political Trust Ratings in Surveys? (I)

# %% [raw]
# ---
#
# ## Asking Why: Is there an Affective Component of Political Trust Ratings in Surveys? (II)
#
#
#
# ---

# %% [markdown]
# ## Asking Why: Is there an Affective Component of Political Trust Ratings in Surveys? (III)

# %% [raw]
# ---
#
# ## Summary & Discussion
#
# - summarize findings
# - discuss challenges: e.g., sample sizes
#
#
# ---

# %% [markdown]
# ## Conclusion
#
# - make real recommendations (s. Fragen Florian)
# - outline future research agendas

# %% [markdown]
# ---
#
# ## Thank you for your Attention!
#
#
# <!-- for mock talk only  -->
# Your Questions, feedback, comments, tips? Thank you!
#
#
# note: host slides on github
